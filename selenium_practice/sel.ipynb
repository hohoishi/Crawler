# %%
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 如果不做設置, chrome視窗有可能會自動關閉
options = webdriver.ChromeOptions()
options.add_experimental_option("detach", True)

driver = webdriver.Chrome(options=options,
                          service=Service(ChromeDriverManager().install()))

url = "https://www.google.com"
driver.get(url)
driver.maximize_window()

element =  driver.find_element(By.TAG_NAME,'input' )
#區塊.click() 區塊.sendkeys('')
element.send_keys('Elwing老師')

# %%
import time
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 如果不做設置, chrome視窗有可能會自動關閉
options = webdriver.ChromeOptions()
options.add_experimental_option("detach", True)

driver = webdriver.Chrome(options=options,
                          service=Service(ChromeDriverManager().install()))

url = "https://www.google.com"
driver.get(url)
driver.maximize_window()

element = driver.find_element(By.CLASS_NAME, "gLFyf")
# 區塊.click() 區塊.send_keys("")
element.send_keys("Elwing老師")
element.send_keys(Keys.ENTER)
time.sleep(1)
divs = driver.find_elements(By.CLASS_NAME, "yuRUbf")
for div in divs:
    link = div.find_element(By.TAG_NAME, "a")
    print(link.get_attribute("href"))
    print(link.text)
    print("-" * 30)

time.sleep(3)
driver.close()
# Out:
# https://www.facebook.com/GrandCoder/
# GrandCoder - Elwing老師程式教室
# Facebook
# https://www.facebook.com › GrandCoder
# ------------------------------
# https://www.tibame.com/teacher/3f0b810f
# 周凡剛的講師專頁
# TibaMe
# https://www.tibame.com › teacher
# ------------------------------
# https://www.facebook.com/groups/pythontw/posts/10163088080563438/
# Python Taiwan | Hi, 我是Elwing
# Facebook
# https://www.facebook.com › groups › pythontw › posts
# ------------------------------
# https://elwingsite.wordpress.com/
# Elwing的程式設計課– 程式設計課程與程式設計心得
# WordPress.com
# https://elwingsite.wordpress.com
# ------------------------------
# https://www.tibame.com/course/502
# 機器學習實戰| 緯育TibaMe | 提拔我的學習力提升職場競爭力
# TibaMe
# https://www.tibame.com › course
# ------------------------------
# https://hackmd.io/@Annie-learning-ai/By0ZNdlCw
# 0104 深度學習
# HackMD
# https://hackmd.io › ...
# ------------------------------
# https://github.com/littlefish0331/MonteCarlo_simulation
# ...
